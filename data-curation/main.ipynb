# %%
from src.data_loader import JeopardyDataLoader
from src.classifier import HuggingFaceJeopardyClassifier

# %%
import pandas as pd

# %%
df = pd.read_json("JEOPARDY_QUESTIONS1.json")

# %%
input = "JEOPARDY_QUESTIONS1.json"
max_samples = 1000

model_name = "Qwen/Qwen3-4B-Instruct-2507"
batch_size = 32
max_new_tokens = 500

output_dir = "output"
n_samples = 100

predictions_file = "predictions.json"

# %%
loader = JeopardyDataLoader(input)
data = loader.load_and_clean(max_samples=max_samples)
# Out:
# 2025-11-29 01:13:29,760 - INFO - Loading data from JEOPARDY_QUESTIONS1.json
# 2025-11-29 01:13:30,278 - INFO - Loaded 1,000 samples (limited to 1,000)
# 2025-11-29 01:13:30,279 - INFO - Cleaning data...
# 2025-11-29 01:13:30,281 - INFO - Cleaned 1,000 records

# %%
stats = loader.get_statistics(data)
stats
# Out:
# {'total_questions': 1000, 'unique_categories': 933, 'unique_shows': 881}

# %%
total_dataset_size = len(data)
total_dataset_size
# Out:
# 1000

# %%
classifier = HuggingFaceJeopardyClassifier(model_name=model_name, batch_size=batch_size)
# Out:
# 2025-11-29 01:13:30,296 - INFO - Loading model: Qwen/Qwen3-30B-A3B-Instruct-2507
# 2025-11-29 01:13:30,297 - INFO - This may take a few moments...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use cuda:0
# 2025-11-29 01:13:58,742 - INFO - Model loaded successfully on device: auto

# %%
predictions = classifier.classify_dataset(data, 1, "test.json")
# Out:
# 2025-11-29 01:13:58,747 - INFO -
# Classifying 1,000 questions with model Qwen/Qwen3-30B-A3B-Instruct-2507
# 2025-11-29 01:13:58,748 - INFO - Batch size: 32
# Processing questions:   3%|▎         | 32/1000 [00:08<04:05,  3.95it/s]
# 2025-11-29 01:14:06,871 - INFO -
# Checkpoint saved at question 32/1000
# Processing questions:   6%|▋         | 64/1000 [00:14<03:32,  4.41it/s]
# 2025-11-29 01:14:13,538 - INFO -
# Checkpoint saved at question 64/1000
# Processing questions:  10%|▉         | 96/1000 [00:21<03:23,  4.45it/s]
# 2025-11-29 01:14:20,662 - INFO -
# Checkpoint saved at question 96/1000
# Processing questions:  13%|█▎        | 128/1000 [00:29<03:15,  4.46it/s]
# 2025-11-29 01:14:27,811 - INFO -
# Checkpoint saved at question 128/1000
# Processing questions:  16%|█▌        | 160/1000 [00:36<03:07,  4.47it/s]
# 2025-11-29 01:14:34,932 - INFO -
# Checkpoint saved at question 160/1000
# Processing questions:  19%|█▉        | 192/1000 [00:43<02:59,  4.51it/s]
# 2025-11-29 01:14:41,896 - INFO -
# Checkpoint saved at question 192/1000
# Processing questions:  22%|██▏       | 224/1000 [00:50<02:56,  4.40it/s]
# 2025-11-29 01:14:49,562 - INFO -
# Checkpoint saved at question 224/1000
# Processing questions:  26%|██▌       | 256/1000 [00:57<02:46,  4.46it/s]
# 2025-11-29 01:14:56,533 - INFO -
# Checkpoint saved at question 256/1000
# Processing questions:  29%|██▉       | 288/1000 [01:04<02:38,  4.49it/s]
# 2025-11-29 01:15:03,536 - INFO -
# Checkpoint saved at question 288/1000
# Processing questions:  32%|███▏      | 320/1000 [01:12<02:33,  4.42it/s]
# 2025-11-29 01:15:11,017 - INFO -
# Checkpoint saved at question 320/1000
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processing questions:  35%|███▌      | 352/1000 [01:19<02:24,  4.50it/s]
# 2025-11-29 01:15:17,848 - INFO -
# Checkpoint saved at question 352/1000
# Processing questions:  38%|███▊      | 384/1000 [01:25<02:15,  4.56it/s]
# 2025-11-29 01:15:24,644 - INFO -
# Checkpoint saved at question 384/1000
# Processing questions:  42%|████▏     | 416/1000 [01:32<02:06,  4.61it/s]
# 2025-11-29 01:15:31,436 - INFO -
# Checkpoint saved at question 416/1000
# Processing questions:  45%|████▍     | 448/1000 [01:40<02:03,  4.48it/s]
# 2025-11-29 01:15:39,014 - INFO -
# Checkpoint saved at question 448/1000
# Processing questions:  48%|████▊     | 480/1000 [01:47<01:55,  4.48it/s]
# 2025-11-29 01:15:46,150 - INFO -
# Checkpoint saved at question 480/1000
# Processing questions:  51%|█████     | 512/1000 [01:55<01:52,  4.35it/s]
# 2025-11-29 01:15:54,029 - INFO -
# Checkpoint saved at question 512/1000
# Processing questions:  54%|█████▍    | 544/1000 [02:02<01:43,  4.39it/s]
# 2025-11-29 01:16:01,167 - INFO -
# Checkpoint saved at question 544/1000
# Processing questions:  58%|█████▊    | 576/1000 [02:09<01:36,  4.38it/s]
# 2025-11-29 01:16:08,486 - INFO -
# Checkpoint saved at question 576/1000
# Processing questions:  61%|██████    | 608/1000 [02:16<01:28,  4.43it/s]
# 2025-11-29 01:16:15,554 - INFO -
# Checkpoint saved at question 608/1000
# Processing questions:  64%|██████▍   | 640/1000 [02:23<01:21,  4.43it/s]
# 2025-11-29 01:16:22,749 - INFO -
# Checkpoint saved at question 640/1000
# Processing questions:  67%|██████▋   | 672/1000 [02:30<01:12,  4.51it/s]
# 2025-11-29 01:16:29,559 - INFO -
# Checkpoint saved at question 672/1000
# Processing questions:  70%|███████   | 704/1000 [02:37<01:05,  4.53it/s]
# 2025-11-29 01:16:36,558 - INFO -
# Checkpoint saved at question 704/1000
# Processing questions:  74%|███████▎  | 736/1000 [02:45<00:59,  4.45it/s]
# 2025-11-29 01:16:44,029 - INFO -
# Checkpoint saved at question 736/1000
# Processing questions:  77%|███████▋  | 768/1000 [02:52<00:51,  4.50it/s]
# 2025-11-29 01:16:50,985 - INFO -
# Checkpoint saved at question 768/1000
# Processing questions:  80%|████████  | 800/1000 [02:59<00:44,  4.47it/s]
# 2025-11-29 01:16:58,223 - INFO -
# Checkpoint saved at question 800/1000
# Processing questions:  83%|████████▎ | 832/1000 [03:06<00:36,  4.56it/s]
# 2025-11-29 01:17:04,929 - INFO -
# Checkpoint saved at question 832/1000
# Processing questions:  86%|████████▋ | 864/1000 [03:13<00:29,  4.55it/s]
# 2025-11-29 01:17:12,011 - INFO -
# Checkpoint saved at question 864/1000
# Processing questions:  90%|████████▉ | 896/1000 [03:20<00:23,  4.49it/s]
# 2025-11-29 01:17:19,347 - INFO -
# Checkpoint saved at question 896/1000
# Processing questions:  93%|█████████▎| 928/1000 [03:27<00:15,  4.55it/s]
# 2025-11-29 01:17:26,178 - INFO -
# Checkpoint saved at question 928/1000
# Processing questions:  96%|█████████▌| 960/1000 [03:34<00:08,  4.56it/s]
# 2025-11-29 01:17:33,122 - INFO -
# Checkpoint saved at question 960/1000
# Processing questions:  99%|█████████▉| 992/1000 [03:41<00:01,  4.53it/s]
# 2025-11-29 01:17:40,285 - INFO -
# Checkpoint saved at question 992/1000
# Processing questions: 100%|██████████| 1000/1000 [03:43<00:00,  4.38it/s]
# 2025-11-29 01:17:42,675 - INFO -
# Checkpoint saved at question 1000/1000
# Processing questions: 100%|██████████| 1000/1000 [03:43<00:00,  4.47it/s]
# 2025-11-29 01:17:42,688 - INFO -
# Classification complete! Results saved to test.json

# %%
len(predictions)
# Out:
# 1000

# %%
predictions
# Out:
# [{'category': 'NEW JERSEYITES',
#   'air_date': '2001-04-20',
#   'question': "'New Jersey-born singer-actor seen here:'",
#   'value': '$600',
#   'answer': 'Jon Bon Jovi',
#   'round': 'Double Jeopardy!',
#   'show_number': '3840',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'RECORD LABELS',
#   'air_date': '2007-01-01',
#   'question': "'In 1980 this DreamWorks SKG partner founded his own record label'",
#   'value': '$600',
#   'answer': 'David Geffen',
#   'round': 'Jeopardy!',
#   'show_number': '5136',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE GREAT EXHIBITION OF 1851',
#   'air_date': '2005-02-24',
#   'question': "'This prince was president of the exhibition commission'",
#   'value': '$200',
#   'answer': 'Prince Albert',
#   'round': 'Jeopardy!',
#   'show_number': '4719',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PEOPLE',
#   'air_date': '1996-11-15',
#   'question': '\'The father of this actor best known as Lt. Frank Drebin in the "Naked Gun" movies was a Canadian Mountie\'',
#   'value': '$200',
#   'answer': 'Leslie Nielsen',
#   'round': 'Jeopardy!',
#   'show_number': '2810',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'SHAKESPEARE',
#   'air_date': '2011-12-14',
#   'question': "'Nahum Tate's 1681 adaptation of this play omitted the Fool & added a love affair between Edgar & Cordelia'",
#   'value': '$1200',
#   'answer': 'King Lear',
#   'round': 'Double Jeopardy!',
#   'show_number': '6268',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ALBUMS THAT ROCK',
#   'air_date': '2009-05-08',
#   'question': '\'"In Your Honor",<br />"The Color and the Shape"\'',
#   'value': '$1600',
#   'answer': 'Foo Fighters',
#   'round': 'Double Jeopardy!',
#   'show_number': '5690',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '"BIO" SCIENCE',
#   'air_date': '2006-09-13',
#   'question': "'Biblical-sounding term for the principle that living organisms develop only from other living organisms'",
#   'value': '$2000',
#   'answer': 'biogenesis',
#   'round': 'Double Jeopardy!',
#   'show_number': '5058',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MADE IN JAPAN',
#   'air_date': '2006-06-14',
#   'question': "'Yukata is a traditional style of this robelike belted garment'",
#   'value': '$200',
#   'answer': 'a kimono',
#   'round': 'Jeopardy!',
#   'show_number': '5023',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE AFRICAN EXPLORER',
#   'air_date': '2006-04-04',
#   'question': '\'On seeing one of these Paul du Chaillu wrote, "He was not afraid of us.  He stood there, and beat his breast..."\'',
#   'value': '$800',
#   'answer': 'a gorilla',
#   'round': 'Double Jeopardy!',
#   'show_number': '4972',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'VWLLSS MMMLS',
#   'air_date': '2011-04-01',
#   'question': "'It's banded:<br />RMDLL'",
#   'value': '$200',
#   'answer': 'an armadillo',
#   'round': 'Jeopardy!',
#   'show_number': '6120',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CHANGE ONE LETTER',
#   'air_date': '2008-10-06',
#   'question': "'You'll make the this, perhaps an A+, if you can dig deep & name this somber earth excavation'",
#   'value': '$800',
#   'answer': 'grade & grave',
#   'round': 'Double Jeopardy!',
#   'show_number': '5536',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'SINGER-SONGWRITERS',
#   'air_date': '1999-11-23',
#   'question': '\'"That Don\'t Impress Me Much"\'',
#   'value': '$300',
#   'answer': 'Shania Twain',
#   'round': 'Jeopardy!',
#   'show_number': '3502',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'BORN & DIED',
#   'air_date': '1999-06-22',
#   'question': "'This author was born in Edinburgh, Scotland in 1850 & died in Samoa in 1894'",
#   'value': '$600',
#   'answer': 'Robert Louis Stevenson',
#   'round': 'Double Jeopardy!',
#   'show_number': '3422',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'VIRTUAL MEDICINE',
#   'air_date': '2007-11-12',
#   'question': '\'(<a href="http://www.j-archive.com/media/2007-11-12_J_07.jpg">Sarah of the Clue Crew reads next to a doctor inserting a large syringe into a simulated abdomen.</a>)<br />This gas that\'s eliminated during respiration is what gets pumped into the abdomen to expand it & give surgeons room to work\'',
#   'value': '$600',
#   'answer': 'carbon dioxide',
#   'round': 'Jeopardy!',
#   'show_number': '5331',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'POT LUCK',
#   'air_date': '1997-04-23',
#   'question': "'Catoctin Mountain Park in northern Maryland is the site of this presidential retreat'",
#   'value': '$100',
#   'answer': 'Camp David',
#   'round': 'Jeopardy!',
#   'show_number': '2923',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE UNITED NATIONS',
#   'air_date': '1995-11-14',
#   'question': "'Under U.N. guidelines, this military operation began January 16, 1991'",
#   'value': '$400',
#   'answer': 'Operation Desert Storm/Persian Gulf War',
#   'round': 'Double Jeopardy!',
#   'show_number': '2577',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'RUSSIAN PAST',
#   'air_date': '2004-01-06',
#   'question': "'In 1903 Russia's Socialist Democratic Labor Party split into 2 groups: the Bolsheviks & this'",
#   'value': '$2000',
#   'answer': 'the Mensheviks',
#   'round': 'Double Jeopardy!',
#   'show_number': '4452',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MOVIES',
#   'air_date': '1984-12-10',
#   'question': '\'Bo Derek film released unrated so it wouldn\'t get an "X"\'',
#   'value': '$200',
#   'answer': 'Bolero',
#   'round': 'Jeopardy!',
#   'show_number': '66',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'HAIL TO THE CHIEF',
#   'air_date': '1992-11-09',
#   'question': '\'In 1791 he wrote that "Science is my passion, and politics, my duty"\'',
#   'value': '$600',
#   'answer': 'Thomas Jefferson',
#   'round': 'Double Jeopardy!',
#   'show_number': '1881',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '"CAN"NED WORDS',
#   'air_date': '2008-02-01',
#   'question': "'A slang term for a French Canadian, or an NHL player from the other side of the country'",
#   'value': '$1200',
#   'answer': 'a Canuck',
#   'round': 'Double Jeopardy!',
#   'show_number': '5390',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'IRAQ',
#   'air_date': '2004-07-20',
#   'question': '\'Dangerous for U.S. forces, the area north & west of Baghdad is this religious-named "triangle"\'',
#   'value': '$2000',
#   'answer': 'Sunni Triangle',
#   'round': 'Double Jeopardy!',
#   'show_number': '4592',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'SURGERY',
#   'air_date': '2009-03-13',
#   'question': '\'(<a href="http://www.j-archive.com/media/2009-03-13_DJ_13.wmv">Sarah of the Clue Crew shows an anatomical diagram on the monitor.</a>)  Named for a 19th-century surgeon, McBurney\'s point, 2/3rds the distance between the umbilicus & the iliac crest of the pelvis, is the most tender abdominal area when this organ is inflamed & often requires surgery\'',
#   'value': '$800',
#   'answer': 'the appendix',
#   'round': 'Double Jeopardy!',
#   'show_number': '5650',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CLEO POTPOURRIO',
#   'air_date': '2000-11-07',
#   'question': '\'A 1989 biography dubbed this singer-dancer "Jazz Cleopatra"\'',
#   'value': '$400',
#   'answer': 'Josephine Baker',
#   'round': 'Jeopardy!',
#   'show_number': '3722',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PALINDROMIC NAMES',
#   'air_date': '2010-11-26',
#   'question': "'In the 10th century 3 Holy Roman Emperors sported this palindromic name'",
#   'value': '$1000',
#   'answer': 'Otto',
#   'round': 'Jeopardy!',
#   'show_number': '6030',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ANIMATION NATION',
#   'air_date': '2011-07-07',
#   'question': '\'"Dodgebrawl" & "Brunch of Disgustingness" were episodes set on this title "Survivor " -like "island"\'',
#   'value': '$1600',
#   'answer': 'Total Drama Island',
#   'round': 'Double Jeopardy!',
#   'show_number': '6189',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'NEWSPAPER COMICS',
#   'air_date': '2005-02-07',
#   'question': '\'This "Horrible" Viking of the comics has a son named Hamlet & a daughter named Honi\'',
#   'value': '$400',
#   'answer': 'Hagar the Horrible',
#   'round': 'Jeopardy!',
#   'show_number': '4706',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'AUTHORS ON AUTHORS',
#   'air_date': '1997-02-20',
#   'question': '\'Ambrose Bierce described this "Earnest" playwright as "That sovereign of insufferables"\'',
#   'value': '$400',
#   'answer': 'Oscar Wilde',
#   'round': 'Double Jeopardy!',
#   'show_number': '2879',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'EDIBLE NAMES',
#   'air_date': '1986-10-03',
#   'question': '\'In 1977, this corpulent crooner came onto the pop scene like a "bat out of hell"\'',
#   'value': '$600',
#   'answer': 'Meat Loaf',
#   'round': 'Double Jeopardy!',
#   'show_number': '475',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ARCHAEOLOGY',
#   'air_date': '1997-01-15',
#   'question': "'A recent study suggests that this 3.2-million-year-old skeleton of a female is actually a male'",
#   'value': '$400',
#   'answer': '"Lucy"',
#   'round': 'Jeopardy!',
#   'show_number': '2853',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PICK A PLANET',
#   'air_date': '2010-01-01',
#   'question': "'Leda is its 13th moon'",
#   'value': '$2000',
#   'answer': 'Jupiter',
#   'round': 'Double Jeopardy!',
#   'show_number': '5825',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'AUSSIE CAPITALS',
#   'air_date': '2006-01-30',
#   'question': "'This city's harbor was discovered in 1839 by John Stokes, surveyor aboard the HMS Beagle'",
#   'value': '$1200',
#   'answer': 'Darwin',
#   'round': 'Double Jeopardy!',
#   'show_number': '4926',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ZOOLOGY',
#   'air_date': '1998-06-24',
#   'question': "'These wingless bloodsuckers often infest sleeping quarters; don't let 'em bite!'",
#   'value': '$200',
#   'answer': 'Bedbugs',
#   'round': 'Double Jeopardy!',
#   'show_number': '3198',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "YOU'VE GOT BAGGAGE",
#   'air_date': '2010-03-08',
#   'question': "'A small trunk named for its placement at the end of a bed'",
#   'value': '$600',
#   'answer': 'a footlocker',
#   'round': 'Jeopardy!',
#   'show_number': '5871',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CAMILLA',
#   'air_date': '2001-12-06',
#   'question': "'Camilla's great-grandmother, Alice Keppel, was a mistress of this early 20th century king, seen here'",
#   'value': '$1000',
#   'answer': 'Edward VII',
#   'round': 'Jeopardy!',
#   'show_number': '3974',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'THE MIDTERMS (ELECTIONS, THAT IS)',
#   'air_date': '2011-02-25',
#   'question': "'This former Hewlett-Packard CEO challenged Barbara Boxer for a California Senate seat--byeCarly'",
#   'value': '$1600',
#   'answer': 'Fiorina',
#   'round': 'Double Jeopardy!',
#   'show_number': '6095',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ANIMALS ON THE MAP',
#   'air_date': '1998-03-31',
#   'question': '\'In other words, this vacation area in California\'s San Bernardino Mountains would be "Large Grizzly"\'',
#   'value': '$400',
#   'answer': 'Big Bear',
#   'round': 'Jeopardy!',
#   'show_number': '3137',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MOVIE PEOPLE',
#   'air_date': '2007-01-01',
#   'question': '\'Her many costume designs include the sarong worn by Dorothy Lamour & Redford & Newman\'s suits in "The Sting"\'',
#   'value': '$1600',
#   'answer': 'Edith Head',
#   'round': 'Double Jeopardy!',
#   'show_number': '5136',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ADDICTIONARY',
#   'air_date': '2008-11-28',
#   'question': '\'Mike, we think you have a problem, so we\'re having this, from the Latin for "come between"\'',
#   'value': '$800',
#   'answer': 'an intervention',
#   'round': 'Jeopardy!',
#   'show_number': '5575',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "WHERE'S OSCAR?",
#   'air_date': '2011-05-09',
#   'question': "'He reportedly keeps his 2000 Best Actor Oscar in a chicken coop on his Australian ranch'",
#   'value': '$800',
#   'answer': 'Russell Crowe',
#   'round': 'Jeopardy!',
#   'show_number': '6146',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'TURRETS SYNDROME',
#   'air_date': '2007-05-09',
#   'question': "'The numerically designed Castel del Monte in Italy has 8 towers around a courtyard of this shape'",
#   'value': '$1200',
#   'answer': 'an octagon',
#   'round': 'Double Jeopardy!',
#   'show_number': '5228',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'FORE!',
#   'air_date': '2000-11-06',
#   'question': "'In 1994 this Australian set a scoring record by averaging 68.81 per round for the year'",
#   'value': '$1000',
#   'answer': 'Greg Norman',
#   'round': 'Double Jeopardy!',
#   'show_number': '3721',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'GENERAL SCIENCE',
#   'air_date': '2008-05-20',
#   'question': "'A hydrate contains this compound weakly bound in its crystals'",
#   'value': '$800',
#   'answer': 'water',
#   'round': 'Double Jeopardy!',
#   'show_number': '5467',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '"JON"',
#   'air_date': '2009-10-06',
#   'question': "'In the Bible he's a son of Saul & a close friend of David'",
#   'value': '$1200',
#   'answer': 'Jonathan',
#   'round': 'Double Jeopardy!',
#   'show_number': '5762',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE SOLAR SYSTEM',
#   'air_date': '1999-02-17',
#   'question': "'This famous Martian volcano is about 375 miles wide at the base & over 16 miles high'",
#   'value': '$1000',
#   'answer': 'Olympus Mons',
#   'round': 'Double Jeopardy!',
#   'show_number': '3333',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'FINE',
#   'air_date': '2007-07-18',
#   'question': "'This brand introduced its Extra Fine Point marker in 1979 & went Ultra Fine in 1989'",
#   'value': '$400',
#   'answer': 'Sharpie',
#   'round': 'Jeopardy!',
#   'show_number': '5278',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'U.S. GEOGRAPHY IN SONG',
#   'air_date': '2005-05-24',
#   'question': '\'Sure, you studied presidents & state birds, but how the Beastie Boys & their "No Sleep Till" here\'',
#   'value': '$1000',
#   'answer': 'Brooklyn',
#   'round': 'Jeopardy!',
#   'show_number': '4782',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'WHILE YOU WERE "OUT"',
#   'air_date': '2004-10-11',
#   'question': "'Daniel Webster was a member of its class of 1801'",
#   'value': '$2000',
#   'answer': 'Dartmouth',
#   'round': 'Double Jeopardy!',
#   'show_number': '4621',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'AMERICAN HISTORY',
#   'air_date': '2002-02-25',
#   'question': "'A 1963 treaty with Mexico settled a boundary dispute between Ciudad Juarez & this Texas city'",
#   'value': '$1000',
#   'answer': 'El Paso',
#   'round': 'Jeopardy!',
#   'show_number': '4031',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'OCCUPATIONAL WORDS',
#   'air_date': '2006-05-24',
#   'question': "'It's the French word for head, boss, top man'",
#   'value': '$2,000',
#   'answer': 'chef',
#   'round': 'Double Jeopardy!',
#   'show_number': '5008',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THANKS FOR THE MEMOIRS',
#   'air_date': '2011-04-14',
#   'question': '\'Ingrid Betancourt\'s "Even Silence Has an End" recounts her 6 years of captivity in the jungles of this country\'',
#   'value': '$400',
#   'answer': 'Colombia',
#   'round': 'Jeopardy!',
#   'show_number': '6129',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'ART HEISTS',
#   'air_date': '2010-06-08',
#   'question': "'After this painting went missing from the Louvre in 1911, people lined up just to view the empty space'",
#   'value': '$400',
#   'answer': 'the Mona Lisa',
#   'round': 'Double Jeopardy!',
#   'show_number': '5937',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CECIL',
#   'air_date': '2007-05-17',
#   'question': "'Cecil Day founded this motel chain in 1970'",
#   'value': '$400',
#   'answer': 'Days Inn',
#   'round': 'Jeopardy!',
#   'show_number': '5234',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE 7 ANCIENT WONDERS',
#   'air_date': '2009-12-18',
#   'question': "'Probably built by Nebuchadnezzar II for one of his wives, it was laid out on a terrace, 75 feet above the ground'",
#   'value': '$800',
#   'answer': 'the Hanging Gardens of Babylon',
#   'round': 'Jeopardy!',
#   'show_number': '5815',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'STOCK SYMBOLS',
#   'air_date': '1998-10-26',
#   'question': "'CPB is the symbol for this maker of alphabet soup'",
#   'value': '$200',
#   'answer': "Campbell\\'s",
#   'round': 'Double Jeopardy!',
#   'show_number': '3251',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "'90s POP CULTURE",
#   'air_date': '2006-12-01',
#   'question': '\'It\'s true, the 2 guys passed off as this group didn\'t really sing their hit "Girl You Know It\'s True"\'',
#   'value': '$2000',
#   'answer': 'Milli Vanilli',
#   'round': 'Double Jeopardy!',
#   'show_number': '5115',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'OLD WEST DESPERADOES',
#   'air_date': '2006-06-13',
#   'question': "'At the time of his murder in April 1882, he was living in St. Joseph, Missouri, using the name Thomas Howard'",
#   'value': '$400',
#   'answer': 'Jesse James',
#   'round': 'Double Jeopardy!',
#   'show_number': '5022',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'BLACK & WHITE TV',
#   'air_date': '2004-06-30',
#   'question': '\'It\'s not an Italian white wine, it\'s a cute Italian mouse often featured on "The Ed Sullivan Show"\'',
#   'value': '$1000',
#   'answer': 'Topo Gigio',
#   'round': 'Jeopardy!',
#   'show_number': '4578',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'TENNIS, ANYONE?',
#   'air_date': '2005-10-26',
#   'question': '\'In 1993 he was ranked the world\'s No. 1 tennis player; he "re-peted" as No. 1 5 more years\'',
#   'value': '$200',
#   'answer': 'Pete Sampras',
#   'round': 'Jeopardy!',
#   'show_number': '4858',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'DOGS',
#   'air_date': '1997-02-26',
#   'question': "'This Australian wild dog has been bred with Australian herding dogs'",
#   'value': '$500',
#   'answer': 'Dingo',
#   'round': 'Jeopardy!',
#   'show_number': '2883',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE PRODUCE DEPARTMENT',
#   'air_date': '2006-09-20',
#   'question': "'Plums & peaches are classified as freestone, semifreestone or this'",
#   'value': '$2000',
#   'answer': 'cling(stone)',
#   'round': 'Double Jeopardy!',
#   'show_number': '5063',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ANCIENT WORLD',
#   'air_date': '1990-05-17',
#   'question': "'In the 1st Century the Trung sisters headed Vietnam's revolt against the Han overlords from this country'",
#   'value': '$200',
#   'answer': 'China',
#   'round': 'Double Jeopardy!',
#   'show_number': '1329',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'FAMOUS PAINTINGS',
#   'air_date': '2000-05-30',
#   'question': '\'In the early 19th century, this Spaniard created a sensation with his "Majas" paintings, one clothed & one nude\'',
#   'value': '$300',
#   'answer': 'Francisco Goya',
#   'round': 'Jeopardy!',
#   'show_number': '3637',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE ANIMAL KINGDOM',
#   'air_date': '1998-06-16',
#   'question': '\'This type of catfish can generate a 450-volt shock, less than the "eel" of the same name\'',
#   'value': '$200',
#   'answer': 'Electric catfish',
#   'round': 'Jeopardy!',
#   'show_number': '3192',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ALL-AMERICAN FOOD',
#   'air_date': '2000-06-05',
#   'question': "'Named for the city of its birth, deep-dish or pan pizza is also called this'",
#   'value': '$400',
#   'answer': 'Chicago-style pizza',
#   'round': 'Jeopardy!',
#   'show_number': '3641',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'COLUMNISTS',
#   'air_date': '1996-04-01',
#   'question': "'Formerly a Nixon speechwriter, he's now known for his syndicated column on language'",
#   'value': '$500',
#   'answer': 'William Safire',
#   'round': 'Double Jeopardy!',
#   'show_number': '2676',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'A SEEDY CATEGORY',
#   'air_date': '2011-01-11',
#   'question': "'You might say the black oil type of these is for the birds, since it's the most popular food used in feeders'",
#   'value': '$1000',
#   'answer': 'sunflower seeds',
#   'round': 'Jeopardy!',
#   'show_number': '6062',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ACTING OUT',
#   'air_date': '2011-03-16',
#   'question': '\'In the current economy, many people are trying to do <a href="http://www.j-archive.com/media/2011-03-16_J_29.wmv">this</a>\'',
#   'value': '$800',
#   'answer': 'make ends meet',
#   'round': 'Jeopardy!',
#   'show_number': '6108',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'EASTERN EUROPE',
#   'air_date': '1990-03-14',
#   'question': "'Albania broke diplomatic relations with the Soviet Union in 1961 & became allied with this Asian power'",
#   'value': '$200',
#   'answer': 'China',
#   'round': 'Double Jeopardy!',
#   'show_number': '1283',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '"WHITE"',
#   'air_date': '2006-05-02',
#   'question': "'Calcium carbonate conglomeration in England's county Kent'",
#   'value': '$1,400',
#   'answer': 'the White Cliffs of Dover',
#   'round': 'Jeopardy!',
#   'show_number': '4992',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'FABRICS',
#   'air_date': '2011-12-15',
#   'question': '\'To purchase Harris tweed at its source, you\'ll have to travel to these "outer" Scottish islands\'',
#   'value': '$2000',
#   'answer': 'Hebrides',
#   'round': 'Double Jeopardy!',
#   'show_number': '6269',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'NEWS OF 2005',
#   'air_date': '2006-06-12',
#   'question': "'To the relief of many, on August 8 this Space Shuttle returned safely to Earth following launch problems'",
#   'value': '$400',
#   'answer': 'Discovery',
#   'round': 'Jeopardy!',
#   'show_number': '5021',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'BOOK OF LOVE',
#   'air_date': '2002-09-11',
#   'question': "'Photographer Robert Kincaid has a steamy but brief affair with an Iowa farmer's wife in this '90s love story'",
#   'value': '$400',
#   'answer': '"The Bridges of Madison County"',
#   'round': 'Double Jeopardy!',
#   'show_number': '4143',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PLAY BALL!',
#   'air_date': '2008-07-03',
#   'question': "'A manager sounds like an army general when he uses this system of alternating players at the same position'",
#   'value': '$800',
#   'answer': 'a platoon',
#   'round': 'Double Jeopardy!',
#   'show_number': '5499',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CONGRESSIONAL BEFORE & AFTER',
#   'air_date': '2007-12-27',
#   'question': "'The North Carolina senator grown in Hawaii by one company since 1851'",
#   'value': '$800',
#   'answer': 'Elizabeth Dole Pineapple',
#   'round': 'Double Jeopardy!',
#   'show_number': '5364',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "IT'S ANDREW!",
#   'air_date': '2011-11-17',
#   'question': "'In 1901 he sold his steel company to J.P. Morgan for a tidy $250 million'",
#   'value': '$1200',
#   'answer': 'Carnegie',
#   'round': 'Double Jeopardy!',
#   'show_number': '6249',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'TV TRIVIA',
#   'air_date': '1990-02-26',
#   'question': "'1 of 2 rotund comics whose weekly variety shows featured the June Taylor Dancers'",
#   'value': '$200',
#   'answer': 'Dom DeLuise & Jackie Gleason',
#   'round': 'Jeopardy!',
#   'show_number': '1271',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'NOTED PUSSYCATS',
#   'air_date': '1997-10-15',
#   'question': '\'Some Mother Goose scholars believe that this was the real queen visited by "Pussycat, Pussycat"\'',
#   'value': '$400',
#   'answer': 'Queen Elizabeth',
#   'round': 'Jeopardy!',
#   'show_number': '3018',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'RHYME THAT STUFF!',
#   'air_date': '2006-09-22',
#   'question': "'Howard or Hilary'",
#   'value': '$400',
#   'answer': 'Duff',
#   'round': 'Double Jeopardy!',
#   'show_number': '5065',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'AMERICAN LITERATURE',
#   'air_date': '1989-11-09',
#   'question': "'She based Little Lord Fauntleroy's costume on one Oscar Wilde wore when he visited her'",
#   'value': '$400',
#   'answer': 'Frances Hodgson Burnett',
#   'round': 'Jeopardy!',
#   'show_number': '1194',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'QUOTES',
#   'air_date': '1992-12-15',
#   'question': '\'Bartlett\'s attributes "Sometimes a cigar is just a cigar" to this Austrian psychoanalyst\'',
#   'value': '$400',
#   'answer': 'Freud',
#   'round': 'Double Jeopardy!',
#   'show_number': '1907',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'WE ARE THE CHAMPIONS',
#   'air_date': '2002-05-10',
#   'question': "'On New Year's Day 2002, this school's Seminoles beat Virginia Tech 30-17 to win the Gator Bowl'",
#   'value': '$400',
#   'answer': 'Florida State University',
#   'round': 'Double Jeopardy!',
#   'show_number': '4085',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THEY WERE DROPOUTS',
#   'air_date': '2010-11-12',
#   'question': "'This dropout & actress was married to the president of Argentina from 1946 to 1952'",
#   'value': '$1200',
#   'answer': 'Eva Peron',
#   'round': 'Double Jeopardy!',
#   'show_number': '6020',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ALEXANDER POPE-POURRI',
#   'air_date': '2000-01-31',
#   'question': '\'"But thousands die, without or this & that, die, and endow a college, or" this pet\'',
#   'value': '$400',
#   'answer': 'Cat',
#   'round': 'Double Jeopardy!',
#   'show_number': '3551',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PRO FOOTBALL',
#   'air_date': '2004-09-09',
#   'question': '\'(<a href="http://www.j-archive.com/media/2004-09-09_J_30.jpg" target="_blank">I’m Hall of Fame running back John Riggins.</a>)  In 1983 I rushed for a then record 24 TDs; the Redskins offensive line who opened holes for me had this nickname\'',
#   'value': '$1000',
#   'answer': 'Hogs',
#   'round': 'Jeopardy!',
#   'show_number': '4599',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '15 LETTERS OR MORE',
#   'air_date': '2011-07-29',
#   'question': "'After the physicist who discovered X-rays, it's another name for a doctor who interprets X-rays'",
#   'value': '$2000',
#   'answer': 'a roentgenologist',
#   'round': 'Double Jeopardy!',
#   'show_number': '6205',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'JAZZ',
#   'air_date': '2005-03-28',
#   'question': '\'Louis Armstrong\'s mentor, this jazz "King" was ruined by dental trouble & died while working as a poolroom marker\'',
#   'value': '$2000',
#   'answer': '"King" Oliver',
#   'round': 'Double Jeopardy!',
#   'show_number': '4741',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'IN THE DICTIONARY',
#   'air_date': '2003-07-10',
#   'question': "'Number of partners in a duumvirate'",
#   'value': '$200',
#   'answer': '2',
#   'round': 'Jeopardy!',
#   'show_number': '4359',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ASTRONOMERS',
#   'air_date': '1990-04-24',
#   'question': "'Born Niklas Koppernigk, he was a canon of Frauenberg Cathedral from 1497 until his death in 1543'",
#   'value': '$200',
#   'answer': 'Nicolaus Copernicus',
#   'round': 'Double Jeopardy!',
#   'show_number': '1312',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CLUBS & ORGANIZATIONS',
#   'air_date': '2001-06-11',
#   'question': '\'The "big cats" who founded this organization in Chicago in 1917 allow no business discussions at meetings\'',
#   'value': '$200',
#   'answer': 'Lions Club',
#   'round': 'Double Jeopardy!',
#   'show_number': '3876',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MUSEUMS',
#   'air_date': '2004-09-29',
#   'question': "'For nearly 4 centuries, what is now the Topkapi Palace Museum was the residence of this empire's sultans'",
#   'value': '$800',
#   'answer': 'the Ottoman Empire',
#   'round': 'Double Jeopardy!',
#   'show_number': '4613',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'U.S. PRESIDENTS',
#   'air_date': '2010-05-26',
#   'question': '\'"A Country of Vast Designs" is a book subtitled him, "the Mexican War & the Conquest of the American Continent"\'',
#   'value': '$2000',
#   'answer': 'James K. Polk',
#   'round': 'Double Jeopardy!',
#   'show_number': '5928',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'GOOD DOGGIE',
#   'air_date': '2008-06-11',
#   'question': "'Garm, a hound in Norse mythology, is often compared to this canine of Greek mythology'",
#   'value': '$1,700',
#   'answer': 'Cerberus',
#   'round': 'Jeopardy!',
#   'show_number': '5483',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'NEWS ON THE MARCH',
#   'air_date': '2006-03-29',
#   'question': "'Nationalists from this Commonwealth attacked the U.S. Capitol March 1, 1954, injuring 5 representatives'",
#   'value': '$800',
#   'answer': 'Puerto Rico',
#   'round': 'Double Jeopardy!',
#   'show_number': '4968',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'LITERARY E-MAIL ADDRESSES',
#   'air_date': '2011-01-05',
#   'question': "'aka-smeagol@my-precious.info'",
#   'value': '$800',
#   'answer': 'Gollum',
#   'round': 'Double Jeopardy!',
#   'show_number': '6058',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'PHILOSOPHERS',
#   'air_date': '2011-05-20',
#   'question': "'Followers of this 13th Century Italian thinker are known as Thomists'",
#   'value': '$800',
#   'answer': 'Thomas Aquinas',
#   'round': 'Double Jeopardy!',
#   'show_number': '6155',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "I'LL GO MINE",
#   'air_date': '2005-06-16',
#   'question': '\'To save money on a ring, I\'ll go mine this form of carbon seen <a href="http://www.j-archive.com/media/2005-06-16_DJ_21.jpg" target="_blank">here</a> and make a synthetic diamond\'',
#   'value': '$2000',
#   'answer': 'graphite',
#   'round': 'Double Jeopardy!',
#   'show_number': '4799',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MARY, MARY',
#   'air_date': '2009-04-30',
#   'question': "'Her name heads a list of women of Galilee in Luke 8:2'",
#   'value': '$800',
#   'answer': 'Mary Magdalene',
#   'round': 'Double Jeopardy!',
#   'show_number': '5684',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'LET ME TAKE YOU DOWN',
#   'air_date': '2009-06-11',
#   'question': '\'Grolier says this man "contributed directly to the collapse of the Romanov dynasty shortly after his own death"\'',
#   'value': '$400',
#   'answer': 'Rasputin',
#   'round': 'Jeopardy!',
#   'show_number': '5714',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'ESPAÑOL',
#   'air_date': '1990-11-15',
#   'question': "'The traditional title for daughters of the kings of Portugal & Spain'",
#   'value': '$500',
#   'answer': 'infanta',
#   'round': 'Jeopardy!',
#   'show_number': '1429',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'LITERARY BROTHERS',
#   'air_date': '2010-06-11',
#   'question': '\'"The Devil\'s Sooty Brother\' is a lesser-known tale by these real-life German brothers\'',
#   'value': '$800',
#   'answer': 'the Brothers Grimm',
#   'round': 'Double Jeopardy!',
#   'show_number': '5940',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'GOING DOWNTOWN',
#   'air_date': '2007-05-02',
#   'question': "'I'll take the Loop & go to the Field Museum if it's not too windy in this city'",
#   'value': '$200',
#   'answer': 'Chicago',
#   'round': 'Jeopardy!',
#   'show_number': '5223',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'LEGENDARY LIONS',
#   'air_date': '1997-09-08',
#   'question': "'(VIDEO Daily Double):  Comedian seen here with his lion pal Pookie:'",
#   'value': '$900',
#   'answer': 'Soupy Sales',
#   'round': 'Jeopardy!',
#   'show_number': '2991',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': "IT'S ALL ABOUT HER",
#   'air_date': '2011-10-26',
#   'question': '\'"Goodness Had Nothing to Do With It"\'',
#   'value': '$600',
#   'answer': 'Mae West',
#   'round': 'Jeopardy!',
#   'show_number': '6233',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE VOTES ARE IN',
#   'air_date': '2006-06-23',
#   'question': "'In 1993 this U.S. commonwealth voted to maintain its status quo & not become a state'",
#   'value': '$400',
#   'answer': 'Puerto Rico',
#   'round': 'Jeopardy!',
#   'show_number': '5030',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CAPITAL TOURISM',
#   'air_date': '2002-10-08',
#   'question': "'Sir Francis Chantrey's statue of King George IV stands in a corner of this famous London square'",
#   'value': '$400',
#   'answer': 'Trafalgar Square',
#   'round': 'Jeopardy!',
#   'show_number': '4162',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'TITLED HEADS',
#   'air_date': '1984-09-24',
#   'question': "'N.Y. financier Al Grimaldi is next in line for throne of this Mediterranean principality'",
#   'value': None,
#   'answer': 'Monaco',
#   'round': 'Final Jeopardy!',
#   'show_number': '11',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CAN I GET YOUR NUMBER?',
#   'air_date': '2005-03-16',
#   'question': "'The scientific notation for this real number is 23 x 10<sup>6</sup>'",
#   'value': '$1000',
#   'answer': '23 million',
#   'round': 'Jeopardy!',
#   'show_number': '4733',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'COUNTRY TIME',
#   'air_date': '2004-06-02',
#   'question': "'What was long ago called Cush, part of Nubia, is considered to be this African country today'",
#   'value': '$2000',
#   'answer': 'Ethiopia',
#   'round': 'Double Jeopardy!',
#   'show_number': '4558',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'TOUGH TV TRIVIA',
#   'air_date': '1990-11-12',
#   'question': "'For the Bradys it was Tiger, for the Bundys it's Buck'",
#   'value': '$100',
#   'answer': 'the family dog',
#   'round': 'Jeopardy!',
#   'show_number': '1426',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'COLLEGES & UNIVERSITIES',
#   'air_date': '1997-12-04',
#   'question': "'This university near Palo Alto, California was founded by a railroad magnate & named for his son'",
#   'value': '$300',
#   'answer': 'Stanford',
#   'round': 'Jeopardy!',
#   'show_number': '3054',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PENINSULAS',
#   'air_date': '2010-11-16',
#   'question': "'This state's Door Peninsula juts out between Green Bay & Lake Michigan'",
#   'value': '$400',
#   'answer': 'Wisconsin',
#   'round': 'Double Jeopardy!',
#   'show_number': '6022',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '"V" SHALL SEE',
#   'air_date': '2011-01-06',
#   'question': '\'You\'re all wet if you can\'t name <a href="http://www.j-archive.com/media/2011-01-06_J_02.jpg" target="_blank">this</a> location\'',
#   'value': '$400',
#   'answer': 'the Victoria Falls',
#   'round': 'Jeopardy!',
#   'show_number': '6059',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '"B" BOYS',
#   'air_date': '2005-06-23',
#   'question': '\'His 1955 autobiography was titled "Four-Minute Mile"\'',
#   'value': '$800',
#   'answer': 'Roger Bannister',
#   'round': 'Double Jeopardy!',
#   'show_number': '4804',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE WEATHER CHANNEL',
#   'air_date': '2005-01-10',
#   'question': "'In terms of rainfall, it's the driest continent after Antarctica'",
#   'value': '$800',
#   'answer': 'Australia',
#   'round': 'Jeopardy!',
#   'show_number': '4686',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'POP MUSIC',
#   'air_date': '1995-11-20',
#   'question': "'In 1969 Sam Phillips sold this Memphis-based record label to Shelby Singleton of Nashville'",
#   'value': '$400',
#   'answer': 'Sun Records',
#   'round': 'Jeopardy!',
#   'show_number': '2581',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MILITARY MATTERS',
#   'air_date': '2001-01-12',
#   'question': "'In peacetime the Coast Guard is part of this cabinet department, not the Defense Department'",
#   'value': '$800',
#   'answer': 'Transportation',
#   'round': 'Double Jeopardy!',
#   'show_number': '3770',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MIDDLE NAMES',
#   'air_date': '1990-03-19',
#   'question': "'Of Hollywood's Warner Brothers, the one whose middle name was Leonard'",
#   'value': '$500',
#   'answer': 'Jack Leonard Warner',
#   'round': 'Jeopardy!',
#   'show_number': '1286',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'RHYME TIME',
#   'air_date': '2010-05-18',
#   'question': '\'Vexing problem seen <a href="http://www.j-archive.com/media/2010-05-18_DJ_15.wmv">here</a>\'',
#   'value': '$1200',
#   'answer': 'preamble scramble',
#   'round': 'Double Jeopardy!',
#   'show_number': '5922',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "LET'S GO TO GRACELAND",
#   'air_date': '2004-01-08',
#   'question': "'Graceland's Christmas lights go on the Friday after this holiday & stay up through Elvis' birthday festivities in Jan.'",
#   'value': '$400',
#   'answer': 'Thanksgiving',
#   'round': 'Jeopardy!',
#   'show_number': '4454',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'POLITICS',
#   'air_date': '2008-10-27',
#   'question': '\'(<a href="http://www.j-archive.com/media/2008-10-27_DJ_18.jpg" target="_blank">I\'m CNN anchor Soledad O\'Brien.</a>)  Barack Obama can claim favorite son status all over the country; born in Hawaii, he went to college in New York & then moved to this state as a community organizer\'',
#   'value': '$400',
#   'answer': 'Illinois',
#   'round': 'Double Jeopardy!',
#   'show_number': '5551',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ABBREV.',
#   'air_date': '2008-11-13',
#   'question': '\'When used of time, the abbreviation P.M. means this "meridiem"\'',
#   'value': '$1600',
#   'answer': 'post',
#   'round': 'Double Jeopardy!',
#   'show_number': '5564',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'BUSINESS PAIRINGS',
#   'air_date': '2003-06-09',
#   'question': "'Peter Bang's partner in hi-fi's'",
#   'value': '$1600',
#   'answer': 'Svend Olufsen',
#   'round': 'Double Jeopardy!',
#   'show_number': '4336',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'PENINSULAS',
#   'air_date': '2000-10-31',
#   'question': '\'The name of this Greek peninsula means "Island of the Pelops"\'',
#   'value': '$400',
#   'answer': 'Peloponnesis',
#   'round': 'Double Jeopardy!',
#   'show_number': '3717',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'JUST DESSERTS',
#   'air_date': '2008-05-23',
#   'question': "'Sharing its name with a French novel, this candy bar was originally 3 nougat bars'",
#   'value': '$400',
#   'answer': 'Three Musketeers',
#   'round': 'Jeopardy!',
#   'show_number': '5470',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'EXPLORERS',
#   'air_date': '2002-11-21',
#   'question': "'Capt. Robert Fitzroy commanded the Beagle on the 1831-36 expedition with this naturalist'",
#   'value': '$200',
#   'answer': 'Charles Darwin',
#   'round': 'Jeopardy!',
#   'show_number': '4194',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'FASHION HISTORY',
#   'air_date': '1996-10-03',
#   'question': "'Winkle pickers were a pointed style of these worn by British trendsetters in the 1950s'",
#   'value': '$400',
#   'answer': 'shoes',
#   'round': 'Jeopardy!',
#   'show_number': '2779',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "LET'S GET PHYSICAL!",
#   'air_date': '2002-06-04',
#   'question': "'The uterine tubes known as oviducts are also called these, after the man who discovered them'",
#   'value': '$800',
#   'answer': 'the Fallopian tubes',
#   'round': 'Double Jeopardy!',
#   'show_number': '4102',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'WORDS IN AMERICA',
#   'air_date': '2008-04-15',
#   'question': "'Edible paddy product'",
#   'value': '$400',
#   'answer': 'rice',
#   'round': 'Jeopardy!',
#   'show_number': '5442',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PARK PLACE',
#   'air_date': '2008-04-02',
#   'question': "'Cumberland Falls State Resort Park'",
#   'value': '$800',
#   'answer': 'Kentucky',
#   'round': 'Jeopardy!',
#   'show_number': '5433',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'SHARKS!',
#   'air_date': '1997-11-26',
#   'question': "'It's said that black wetsuits attract great white sharks because swimmers resemble these animals'",
#   'value': '$500',
#   'answer': 'Seals',
#   'round': 'Jeopardy!',
#   'show_number': '3048',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
# ...
#   'value': '$1000',
#   'answer': 'Yanni',
#   'round': 'Jeopardy!',
#   'show_number': '5728',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ANNUAL EVENTS',
#   'air_date': '1997-06-09',
#   'question': "'The Ms. Foundation For Women encourages parents to do this on the 4th Thursday in April'",
#   'value': '$900',
#   'answer': 'Take their daughters to work with them',
#   'round': 'Double Jeopardy!',
#   'show_number': '2956',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ASSOCIATIONS',
#   'air_date': '2003-06-19',
#   'question': "'The burglary of this organization's office June 17, 1972 made headlines'",
#   'value': '$800',
#   'answer': 'the Democratic National Committee',
#   'round': 'Jeopardy!',
#   'show_number': '4344',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'SPELL THE LAST NAME',
#   'air_date': '1999-05-14',
#   'question': "'Former Defense Secretary Caspar...'",
#   'value': '$400',
#   'answer': 'W-E-I-N-B-E-R-G-E-R',
#   'round': 'Double Jeopardy!',
#   'show_number': '3395',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': '"BELL"s & "WHISTLE"s',
#   'air_date': '1997-10-14',
#   'question': "'Sailors wore these pants long before they became fashionable in the 1960s'",
#   'value': '$200',
#   'answer': 'Bell-bottoms',
#   'round': 'Jeopardy!',
#   'show_number': '3017',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'NOVEL OPERAS',
#   'air_date': '1990-01-22',
#   'question': "'The Benjamin Britten opera based on this Herman Melville work climaxes with a hanging'",
#   'value': '$1000',
#   'answer': 'Billy Budd',
#   'round': 'Double Jeopardy!',
#   'show_number': '1246',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'GOVERNMENT AT YOUR SERVICE',
#   'air_date': '2006-01-17',
#   'question': "'This draft agency also runs an alternative service program for pacifists in lieu of military service'",
#   'value': '$200',
#   'answer': 'the Selective Service',
#   'round': 'Jeopardy!',
#   'show_number': '4917',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'WEIGHTS & MEASURES',
#   'air_date': '2000-09-18',
#   'question': "'It's the term for 1 full trip around the track'",
#   'value': '$300',
#   'answer': 'Lap',
#   'round': 'Jeopardy!',
#   'show_number': '3686',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CATS & DOGS',
#   'air_date': '2008-10-15',
#   'question': "'A blue-black-tongued dog, or the food it eats'",
#   'value': '$1600',
#   'answer': 'a chow',
#   'round': 'Double Jeopardy!',
#   'show_number': '5543',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'VOLCANOES',
#   'air_date': '1999-10-19',
#   'question': "'Currently inactive, at 19,340 feet it's Africa's highest volcano'",
#   'value': '$400',
#   'answer': 'Mount Kilimanjaro',
#   'round': 'Jeopardy!',
#   'show_number': '3477',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'PRESIDENTIAL TERMS OF SERVICE',
#   'air_date': '1998-06-30',
#   'question': "'March 4, 1797-<br />March 3, 1801'",
#   'value': '$200',
#   'answer': 'John Adams',
#   'round': 'Jeopardy!',
#   'show_number': '3202',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'DROP A LETTER',
#   'air_date': '2011-03-09',
#   'question': "'Drop a letter from the language spoken by the people of Seoul to get this sacred text of Islam'",
#   'value': '$400',
#   'answer': 'Koran/Korean',
#   'round': 'Double Jeopardy!',
#   'show_number': '6103',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '1950s MOVIES',
#   'air_date': '2006-09-25',
#   'question': '\'3 years after "Sunset Boulevard", he won an Oscar for "Stalag 17"\'',
#   'value': '$800',
#   'answer': 'William Holden',
#   'round': 'Double Jeopardy!',
#   'show_number': '5066',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'BAWDY BABES IN BOOKS',
#   'air_date': '2008-01-25',
#   'question': "'This title Flaubert floozy's tryst ends (for a while) when her lover leaves to seek his fortune in Paris'",
#   'value': '$1200',
#   'answer': 'Madame Bovary',
#   'round': 'Double Jeopardy!',
#   'show_number': '5385',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'TIME TO CONVERT',
#   'air_date': '2009-05-04',
#   'question': "'It's the simplest fractional form of .75'",
#   'value': '$400',
#   'answer': '3/4',
#   'round': 'Double Jeopardy!',
#   'show_number': '5686',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MOVERS & SHAKERS',
#   'air_date': '2009-04-20',
#   'question': "'Roberto Clemente died flying supplies to this quake-stricken country in 1972'",
#   'value': '$5,400',
#   'answer': 'Nicaragua',
#   'round': 'Double Jeopardy!',
#   'show_number': '5676',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'FACIAL HAIR',
#   'air_date': '1997-03-14',
#   'question': "'Wearing this kind of beard would turn a nanny into a billy'",
#   'value': '$300',
#   'answer': 'Goatee',
#   'round': 'Jeopardy!',
#   'show_number': '2895',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'OPERETTAS',
#   'air_date': '1993-04-01',
#   'question': '\'The German title of this Lehar operetta is "Die Lustige Witwe"\'',
#   'value': '$700',
#   'answer': 'The Merry Widow',
#   'round': 'Double Jeopardy!',
#   'show_number': '1984',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'OPERAS BY CHARACTERS',
#   'air_date': '2009-04-28',
#   'question': "'1905: Herod & Jokanaan (aka John the Baptist)'",
#   'value': '$1600',
#   'answer': 'Salome',
#   'round': 'Double Jeopardy!',
#   'show_number': '5682',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': '"H"ISTORIC PEOPLE',
#   'air_date': '2000-11-13',
#   'question': "'The first U.S. Secretary of the Treasury, this man is pictured on the $10 bill'",
#   'value': '$100',
#   'answer': 'Alexander Hamilton',
#   'round': 'Jeopardy!',
#   'show_number': '3726',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ASTRONOMY',
#   'air_date': '1996-01-19',
#   'question': "'Betelguese is a red supergiant in this constellation of the hunter'",
#   'value': '$400',
#   'answer': 'Orion',
#   'round': 'Jeopardy!',
#   'show_number': '2625',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'OPERA',
#   'air_date': '1996-04-10',
#   'question': "'Beethoven wrote 4 overtures for this opera'",
#   'value': '$1000',
#   'answer': '"Fidelio"',
#   'round': 'Double Jeopardy!',
#   'show_number': '2683',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'FAULT LINES',
#   'air_date': '2008-12-10',
#   'question': '\'"A total deflation in my gut", noted one astronomer after seeing blurred photos taken by this device in 1990\'',
#   'value': '$800',
#   'answer': 'the Hubble Telescope',
#   'round': 'Jeopardy!',
#   'show_number': '5583',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'JAVA, THE HUT',
#   'air_date': '2007-04-20',
#   'question': '\'After World War II, Paris\'s Cafe de Flore became awash with tourists hoping to find <a href="http://www.j-archive.com/media/2007-04-20_J_30.jpg" target="_blank">this</a> man pondering the purpose of being\'',
#   'value': '$1000',
#   'answer': '(Jean-Paul) Sartre',
#   'round': 'Jeopardy!',
#   'show_number': '5215',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'WEIGHTS & MEASURES',
#   'air_date': '1996-09-10',
#   'question': '\'Following "assay", this 3-letter word is a unit of mass; following "freight", it\'s a unit of capacity\'',
#   'value': '$500',
#   'answer': 'ton',
#   'round': 'Jeopardy!',
#   'show_number': '2762',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '"Y"s UP',
#   'air_date': '2011-05-04',
#   'question': '\'It\'s 3-letter slang for mouth, as in "shut your..."\'',
#   'value': '$200',
#   'answer': 'yap',
#   'round': 'Jeopardy!',
#   'show_number': '6143',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'WHAT KIND OF PAINT YOU USING?',
#   'air_date': '2010-11-16',
#   'question': '\'Rembrandt, for 1669\'s "Return of the Prodigal Son"\'',
#   'value': '$200',
#   'answer': 'oil (paint)',
#   'round': 'Jeopardy!',
#   'show_number': '6022',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'JUST SAY NO',
#   'air_date': '2009-12-18',
#   'question': "'In German, this 4-letter word'",
#   'value': '$1200',
#   'answer': 'nein',
#   'round': 'Double Jeopardy!',
#   'show_number': '5815',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'SCIENTISTS',
#   'air_date': '2001-01-25',
#   'question': '\'Bertrand Russell said that "What Galileo and Newton were to the 17th century," this man "was to the 19th"\'',
#   'value': None,
#   'answer': 'Charles Darwin',
#   'round': 'Final Jeopardy!',
#   'show_number': '3779',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'ROCK BAND INITIALS',
#   'air_date': '2010-05-31',
#   'question': "'Fans popularly refer to them as GN'R'",
#   'value': '$800',
#   'answer': "Guns N\\' Roses",
#   'round': 'Double Jeopardy!',
#   'show_number': '5931',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '17th CENTURY ART',
#   'air_date': '2007-10-30',
#   'question': '\'Claude Lorrain gave new status to this genre with works like "A Pastoral" one, now at Yale\'',
#   'value': '$1600',
#   'answer': 'landscape',
#   'round': 'Double Jeopardy!',
#   'show_number': '5322',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'STORY PROBLEMS',
#   'air_date': '2001-09-24',
#   'question': "'If string licorice is 20 cents a foot, a yard costs this much'",
#   'value': '$100',
#   'answer': '60 cents',
#   'round': 'Jeopardy!',
#   'show_number': '3921',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'LITERATURE',
#   'air_date': '2001-10-04',
#   'question': '\'(<a href="http://www.j-archive.com/media/2001-10-04_DJ_25.jpg" target="_blank">Jimmy of the Clue Crew reports from a water theme park.</a>)  Hey, we can be this title duo from a Lewis Carroll poem\'',
#   'value': '$1000',
#   'answer': 'the Walrus and the Carpenter',
#   'round': 'Double Jeopardy!',
#   'show_number': '3929',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'HISTORIC NAMES',
#   'air_date': '1998-12-02',
#   'question': "'This Dane was a law student in 1560 when a solar eclipse sparked his interest in astronomy'",
#   'value': '$600',
#   'answer': 'Tycho Brahe',
#   'round': 'Double Jeopardy!',
#   'show_number': '3278',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'OCCUPATIONS',
#   'air_date': '2005-10-13',
#   'question': '\'To be this type of translator at the U.N. requires "full auditory comprehension" of 3 of the 6 official U.N. languages\'',
#   'value': '$2000',
#   'answer': 'interpreter',
#   'round': 'Double Jeopardy!',
#   'show_number': '4849',
#   'llm_has_numbers': True,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': "I'M IN CHARGE!",
#   'air_date': '2001-10-19',
#   'question': "'In southern Europe:<br />Prime Minister Silvio Berlusconi'",
#   'value': '$400',
#   'answer': 'Italy',
#   'round': 'Double Jeopardy!',
#   'show_number': '3940',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'GIVE ME A SEA',
#   'air_date': '1999-01-27',
#   'question': "'Scotland's longest river, the Tay, flows into this sea, see?'",
#   'value': '$400',
#   'answer': 'North Sea',
#   'round': 'Double Jeopardy!',
#   'show_number': '3318',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'NOMINATIVE DETERMINISM',
#   'air_date': '2008-10-14',
#   'question': "'Dallas Raines reigns performing this function for KABC-TV in Los Angeles'",
#   'value': '$1200',
#   'answer': 'a weatherman (or meteorologist)',
#   'round': 'Double Jeopardy!',
#   'show_number': '5542',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MUSIC',
#   'air_date': '1995-11-13',
#   'question': "'A composer's works are often numbered & appear with the abbreviation Op., which stands for this'",
#   'value': '$200',
#   'answer': 'Opus',
#   'round': 'Double Jeopardy!',
#   'show_number': '2576',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'THE "GENERAL"',
#   'air_date': '2006-11-06',
#   'question': "'Abbreviated GATT, it's governed world commerce since 1947'",
#   'value': '$2000',
#   'answer': 'General Agreement on Tariffs and Trade',
#   'round': 'Double Jeopardy!',
#   'show_number': '5096',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'LETTER MEN',
#   'air_date': '2007-02-19',
#   'question': "'At his death in 1971, there were more than 1,600 department stores bearing his name'",
#   'value': '$200',
#   'answer': 'J.C. Penney',
#   'round': 'Jeopardy!',
#   'show_number': '5171',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'MIND YOUR BUSINESS',
#   'air_date': '2001-09-12',
#   'question': "'The name of this fruit & vegetable canner came off a hotel in Monterey'",
#   'value': '$1000',
#   'answer': 'Del Monte',
#   'round': 'Double Jeopardy!',
#   'show_number': '3913',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': 'AND FOOD',
#   'air_date': '2007-02-28',
#   'question': "'Types of this fruit include the French nicoise & the Greek kalamata'",
#   'value': '$800',
#   'answer': 'olives',
#   'round': 'Jeopardy!',
#   'show_number': '5178',
#   'llm_has_numbers': False,
#   'llm_has_non_english': True,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'LIGHTLY SCRAMBLED EGGHEADS',
#   'air_date': '2009-02-25',
#   'question': "'Linguist who says the U.S. is a brutal imperialist state: Mona Chomsky'",
#   'value': '$1600',
#   'answer': 'Noam Chomsky',
#   'round': 'Double Jeopardy!',
#   'show_number': '5638',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': True},
#  {'category': '-OLOGIES',
#   'air_date': '2001-04-02',
#   'question': "'An expert in sinology is familiar with the history & customs of this country'",
#   'value': '$200',
#   'answer': 'China',
#   'round': 'Jeopardy!',
#   'show_number': '3826',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False}]
