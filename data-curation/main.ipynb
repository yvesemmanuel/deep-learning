# %%
from src.data_loader import JeopardyDataLoader
from src.classifier import HuggingFaceJeopardyClassifier

# %%
import pandas as pd

# %%
df = pd.read_json("JEOPARDY_QUESTIONS1.json")

# %%
input = "JEOPARDY_QUESTIONS1.json"
max_samples = 5

# %%
loader = JeopardyDataLoader(input)
data = loader.load_and_clean(max_samples=max_samples)
# Out:
# 2025-11-28 22:57:43,172 - INFO - Loading data from JEOPARDY_QUESTIONS1.json
# 2025-11-28 22:57:43,676 - INFO - Loaded 5 samples (limited to 5)
# 2025-11-28 22:57:43,676 - INFO - Cleaning data...
# 2025-11-28 22:57:43,677 - INFO - Cleaned 5 records

# %%
stats = loader.get_statistics(data)
stats
# Out:
# {'total_questions': 5, 'unique_categories': 5, 'unique_shows': 5}

# %%
classifier = HuggingFaceJeopardyClassifier()
# Out:
# 2025-11-28 22:57:43,690 - INFO - Loading model: Qwen/Qwen3-1.7B
# 2025-11-28 22:57:43,690 - INFO - This may take a few moments...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0
# 2025-11-28 22:57:47,263 - INFO - Model loaded successfully on device: auto

# %%
predictions = classifier.classify_dataset(data, 1, "test.json")
# Out:
# 2025-11-28 22:57:47,268 - INFO -
# Classifying 5 questions with model Qwen/Qwen3-1.7B
# 2025-11-28 22:57:47,269 - INFO - Batch size: 8
# Processing questions:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-11-28 22:59:09,517 - WARNING - Error classifying row: No JSON object found in response
# Processing questions: 100%|██████████| 5/5 [01:42<00:00, 20.55s/it]
# 2025-11-28 22:59:30,035 - INFO -
# Checkpoint saved at question 5/5
# Processing questions: 100%|██████████| 5/5 [01:42<00:00, 20.55s/it]
# 2025-11-28 22:59:30,037 - INFO -
# Classification complete! Results saved to test.json

# %%
predictions
# Out:
# [{'category': 'BALLET',
#   'air_date': '1998-07-17',
#   'question': "'Prince Ivan falls in love with an enchanted Tsarevna in Stravinsky's ballet about this magical bird'",
#   'value': '$400',
#   'answer': '"The Firebird"',
#   'round': 'Double Jeopardy!',
#   'show_number': '3215',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'TRANSPORTATION',
#   'air_date': '1991-11-05',
#   'question': "'In 1990 this cruise line founded by a British shipowner celebrated its 150th anniversary'",
#   'value': '$600',
#   'answer': 'the Cunard Line',
#   'round': 'Double Jeopardy!',
#   'show_number': '1652',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'CONTEMPORARY ART MUSEUMS',
#   'air_date': '2005-11-23',
#   'question': "'Founded in 1939, this city's Contemporary Arts Center was at the center of a 1990s 1st Amendment case'",
#   'value': '$6,000',
#   'answer': 'Cincinnati',
#   'round': 'Double Jeopardy!',
#   'show_number': '4878',
#   'llm_has_numbers': True,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': '1984',
#   'air_date': '1990-03-01',
#   'question': "'In December this founder of est announced that he was giving last of his weekend transformation sessions'",
#   'value': '$1000',
#   'answer': 'Werner Erhardt',
#   'round': 'Double Jeopardy!',
#   'show_number': '1274',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False},
#  {'category': 'HEALTH & MEDICINE',
#   'air_date': '2007-12-14',
#   'question': "'There are viral and bacterial types of this, the inflammation of the membranes covering the brain & spinal cord'",
#   'value': '$800',
#   'answer': 'meningitis',
#   'round': 'Double Jeopardy!',
#   'show_number': '5355',
#   'llm_has_numbers': False,
#   'llm_has_non_english': False,
#   'llm_has_unusual_proper_nouns': False}]
